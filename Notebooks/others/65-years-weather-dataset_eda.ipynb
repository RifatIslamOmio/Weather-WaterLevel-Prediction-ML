# %%
# required for jupyter notebook
# %matplotlib inline 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
sns.set(rc={'figure.figsize':(8,6)}) # set sns figure size

import os
import math

# %%
raw_df = pd.read_csv(os.path.join('..', 'Datasets', '65-years-BMD-data', '65 Years of Weather Data Bangladesh (1948 - 2013).csv'))

raw_df.head()
# Out:
#    Unnamed: 0 Station Names  YEAR  Month  Max Temp  Min Temp  Rainfall  \
# 0           0       Barisal  1949      1      29.4      12.3       0.0
# 1           1       Barisal  1950      1      30.0      14.1       0.0
# 2           2       Barisal  1951      1      28.2      12.3       0.0
# 3           3       Barisal  1952      1      26.6      12.3       2.0
# 4           4       Barisal  1953      1      30.0      13.3      10.0
#
#    Relative Humidity  Wind Speed  Cloud Coverage  Bright Sunshine  \
# 0               68.0    0.453704             0.6         7.831915
# 1               77.0    0.453704             0.8         7.831915
# 2               77.0    0.453704             0.6         7.831915
# 3               77.0    0.453704             1.0         7.831915
# 4               75.0    0.453704             1.6         7.831915
#
#    Station Number     X_COR     Y_COR  LATITUDE  LONGITUDE  ALT   Period
# ...

# %%
raw_df = raw_df.drop(columns=['Unnamed: 0'])

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21120 entries, 0 to 21119
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Station Names      21120 non-null  object
#  1   YEAR               21120 non-null  int64
#  2   Month              21120 non-null  int64
#  3   Max Temp           21120 non-null  float64
#  4   Min Temp           21120 non-null  float64
#  5   Rainfall           21120 non-null  float64
#  6   Relative Humidity  21120 non-null  float64
#  7   Wind Speed         21120 non-null  float64
#  8   Cloud Coverage     21120 non-null  float64
#  9   Bright Sunshine    21120 non-null  float64
#  10  Station Number     21120 non-null  int64
#  11  X_COR              21120 non-null  float64
#  12  Y_COR              21120 non-null  float64
#  13  LATITUDE           21120 non-null  float64
#  14  LONGITUDE          21120 non-null  float64
# ...

# %%
raw_df['Rainfall'].max()
# Out:
# 2072.0

# %%
_=sns.scatterplot(data=raw_df, x='Month', y='Rainfall')

# %%
def show_corr_heatmap(df):
    # https://medium.com/@szabo.bibor/how-to-create-a-seaborn-correlation-heatmap-in-python-834c0686b88e

    plt.figure(figsize=(20, 10))

    corr_matrix = df.corr()

    # mask to hide the upper triangle of the symmetric corr-matrix
    # mask = np.triu(np.ones_like(corr_matrix, dtype=np.bool))

    heatmap = sns.heatmap(

        # correlation matrix
        corr_matrix,

        # mask the top triangle of the matrix
        # mask=mask,

        # two-contrast color, different color for + -
        cmap="PiYG",

        # color map range
        vmin=-1, vmax=1,

        # show corr values in the cells
        annot=True
    )

    # set a title
    heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':20}, pad=16);

    plt.show()

# %%
show_corr_heatmap(raw_df)
